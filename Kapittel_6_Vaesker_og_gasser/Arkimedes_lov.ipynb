# %% [markdown]
# $$
# \begin{aligned}
# O &= G_{\text{fortrengt}} \\
#   &= m_v g = \rho_v V g
# \end{aligned}
# $$

# %%
p = 1.0E3                                   # rho vann kg/m**3
V = 100*(1.0E-2)**3                         # Volum i m**3
g = 9.81                                    # tyngdeakselerasjonen N/kg

oppdrift = p * V * g                        # formel

print(f"Oppdriften er {oppdrift:.3f} N")    #:.3 gir tre desimaler
# Out:
# Oppdriften er 0.981 N

# %% [markdown]
# $$
# \begin{aligned}
# \sum \vec{F} &= 0 \\
# K + O - G &= 0 \\
# K &= G - O \\
#
# \end{aligned}
# $$
